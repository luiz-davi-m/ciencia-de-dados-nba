# %% [markdown]
# Fundamentos de ciência de dados - Luiz Davi e Thiago Cavalcanti

# %%
from nba_api_jogadores_utils import analyze_player
from constantes_jogadores import JOGADOR_1_ID, JOGADOR_2_ID, JOGADOR_3_ID, JOGADOR_1, JOGADOR_2, JOGADOR_3, RESULTADOS_P2_PATH

# %% [markdown]
# # RF1 – Precisamos modelar e prever eventos extremos, assim precisamos verificar em cima dos dados que possuímos as probabilidades de ocorrência de pontuação, assistências e rebotes máximos e mínimos. Como pergunta guia responda:

# %% [markdown]
# ### Nikola Jokić

# %%
jogador_dados_path = f"{RESULTADOS_P2_PATH}/rf10_dados_carreira_{JOGADOR_1_ID}.csv"

analyze_player(jogador_dados_path, 50, 20, 20, JOGADOR_1)
# Out:
# Pontos:
# Probabilidade de marcar acima de X: 1.0000
# Probabilidade de atingir ou exceder X: 1.0000
# Probabilidade de atingir ou ficar abaixo de X: 0.0000
# Proporção de valores menores ou iguais a X: 0.0000
# Proporção de valores menores que X: 0.0000
#
# Rebotes:
# Probabilidade de marcar acima de X: 1.0000
# Probabilidade de atingir ou exceder X: 1.0000
# Probabilidade de atingir ou ficar abaixo de X: 0.0000
# Proporção de valores menores ou iguais a X: 0.0000
# Proporção de valores menores que X: 0.0000
#
# Assistências:
# Probabilidade de marcar acima de X: 1.0000
# Probabilidade de atingir ou exceder X: 1.0000
# Probabilidade de atingir ou ficar abaixo de X: 0.0000
# Proporção de valores menores ou iguais a X: 0.0000
# Proporção de valores menores que X: 0.0000

# %% [markdown]
# ### Michael Porter Jr.

# %%
jogador_dados_path = f"{RESULTADOS_P2_PATH}/rf10_dados_carreira_{JOGADOR_2_ID}.csv"

analyze_player(jogador_dados_path, 50, 20, 20, JOGADOR_2)
# Out:
# Pontos:
# Probabilidade de marcar acima de X: 0.9735
# Probabilidade de atingir ou exceder X: 0.9738
# Probabilidade de atingir ou ficar abaixo de X: 0.0265
# Proporção de valores menores ou iguais a X: 0.0265
# Proporção de valores menores que X: 0.0262
#
# Rebotes:
# Probabilidade de marcar acima de X: 0.9875
# Probabilidade de atingir ou exceder X: 0.9878
# Probabilidade de atingir ou ficar abaixo de X: 0.0125
# Proporção de valores menores ou iguais a X: 0.0125
# Proporção de valores menores que X: 0.0122
#
# Assistências:
# Probabilidade de marcar acima de X: 0.9419
# Probabilidade de atingir ou exceder X: 0.9469
# Probabilidade de atingir ou ficar abaixo de X: 0.0581
# Proporção de valores menores ou iguais a X: 0.0581
# Proporção de valores menores que X: 0.0531

# %% [markdown]
# ### Jamal Murray

# %%
jogador_dados_path = f"{RESULTADOS_P2_PATH}/rf10_dados_carreira_{JOGADOR_3_ID}.csv"

analyze_player(jogador_dados_path, 50, 20, 20, JOGADOR_3)
# Out:
# Pontos:
# Probabilidade de marcar acima de X: 1.0000
# Probabilidade de atingir ou exceder X: 1.0000
# Probabilidade de atingir ou ficar abaixo de X: 0.0000
# Proporção de valores menores ou iguais a X: 0.0000
# Proporção de valores menores que X: 0.0000
#
# Rebotes:
# Probabilidade de marcar acima de X: 1.0000
# Probabilidade de atingir ou exceder X: 1.0000
# Probabilidade de atingir ou ficar abaixo de X: 0.0000
# Proporção de valores menores ou iguais a X: 0.0000
# Proporção de valores menores que X: 0.0000
#
# Assistências:
# Probabilidade de marcar acima de X: 1.0000
# Probabilidade de atingir ou exceder X: 1.0000
# Probabilidade de atingir ou ficar abaixo de X: 0.0000
# Proporção de valores menores ou iguais a X: 0.0000
# Proporção de valores menores que X: 0.0000
